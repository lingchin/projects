# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Stores.csv")
df_copy=df.copy()

# %%
df.head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620

# %%
df.isnull().sum()
# Out:
# Store ID                0
# Store_Area              0
# Items_Available         0
# Daily_Customer_Count    0
# Store_Sales             0
# dtype: int64

# %%
df.describe()
# Out:
#         Store ID    Store_Area  Items_Available  Daily_Customer_Count  \
# count  896.000000   896.000000       896.000000            896.000000
# mean   448.500000  1485.409598      1782.035714            786.350446
# std    258.797218   250.237011       299.872053            265.389281
# min      1.000000   775.000000       932.000000             10.000000
# 25%    224.750000  1316.750000      1575.500000            600.000000
# 50%    448.500000  1477.000000      1773.500000            780.000000
# 75%    672.250000  1653.500000      1982.750000            970.000000
# max    896.000000  2229.000000      2667.000000           1560.000000
#
#          Store_Sales
# count     896.000000
# mean    59351.305804
# std     17190.741895
# min     14920.000000
# 25%     46530.000000
# 50%     58605.000000
# 75%     71872.500000
# max    116320.000000

# %% [markdown]
# Check out some relationships if any

# %%
sns.regplot(x=df['Store_Area'], y=df['Store_Sales'], data=df);

# %%
sns.regplot(x=df['Daily_Customer_Count'], y=df['Store_Sales'], data=df);

# %%
sns.regplot(x=df['Items_Available'], y=df['Store_Sales'], data=df);

# %%
sns.regplot(x=df['Items_Available'], y=df['Daily_Customer_Count'], data=df);

# %% [markdown]
# # First Conclusion:
#  - weak positive relationship between size of stores and store sales
#  - no relationship between number of daily customer count and store sales
#  - small positive relationship between number of items available and store sales
#  - small negative relationship between number of items available and daily customer count

# %% [markdown]
# What's the distribution of df_copy

# %%
sns.histplot(df_copy['Store_Sales'], bins=50);

# %%
sns.histplot(df_copy['Store_Area'], bins=50);

# %%
sns.histplot(df_copy['Daily_Customer_Count'], bins=50);

# %%
df_copy['Sales_per_cust']=df_copy['Store_Sales']/df_copy['Daily_Customer_Count']

# %%
sns.histplot(df_copy['Sales_per_cust'], bins=500);
plt.xlim((0,500))
# Out:
# (0.0, 500.0)

# %% [markdown]
# ## How many stores with area in the top 25% but with sales in the lower 25%

# %%
perc_75_size = df_copy.describe().iloc[6,1]
perc_25_sales = df_copy.describe().iloc[4,4]
df_poor=df_copy[(df_copy['Store_Area']>perc_75_size) & (df_copy['Store_Sales']< perc_25_sales)]
df_poor.sample(10)
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  \
# 135        136        1667             1993                   740
# 78          79        1720             2044                   960
# 824        825        1778             2133                   280
# 289        290        1979             2364                   660
# 453        454        1808             2154                   990
# 561        562        1767             2158                   530
# 652        653        1809             2145                   940
# 19          20        1940             2340                   980
# 372        373        1876             2254                  1340
# 117        118        1712             2046                   460
#
#      Store_Sales  Sales_per_cust
# 135        42840       57.891892
# 78         38660       40.270833
# 824        45950      164.107143
# 289        30810       46.681818
# 453        35220       35.575758
# 561        41540       78.377358
# ...

# %%
num_poor_stores = len(df_poor)
print(f"No. of stores with area in the top 25% but with sales in the lower 25% = {num_poor_stores}")
# Out:
# No. of stores with area in the top 25% but with sales in the lower 25% = 44

# %%
percentage_poor = round((num_poor_stores/len(df_copy) * 100),2)
print(f"percentage of stores under performing = {percentage_poor}%")
# Out:
# percentage of stores under performing = 4.91%

# %% [markdown]
# # Second Conclusion:
# - these stores might be new or fairly new, may not have had enough traction
# - these stores might be stores that keep the brand alive in the area, though make poor sales per size

# %% [markdown]
# # scale the features in preparation for ML

# %%
features_list=df.columns[1:-1]
features_list
# Out:
# Index(['Store_Area', 'Items_Available', 'Daily_Customer_Count'], dtype='object')

# %%
#before scaling, check the spread/outliers
df[features_list].boxplot();

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, max_error
import math

#split the data
X=df[features_list]
y=df['Store_Sales']

Xtrain,Xtest,ytrain, ytest = train_test_split(X,y,test_size=0.3)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
Xtrain[features_list]=scaler.fit_transform(Xtrain[features_list])

Xtrain.describe()
# Out:
#        Store_Area  Items_Available  Daily_Customer_Count
# count  627.000000       627.000000            627.000000
# mean     0.481222         0.478634              0.508929
# std      0.168096         0.170320              0.180476
# min      0.000000         0.000000              0.000000
# 25%      0.369565         0.361305              0.381579
# 50%      0.478261         0.473193              0.506579
# 75%      0.584886         0.585082              0.625000
# max      1.000000         1.000000              1.000000

# %%
model=LinearRegression()
model.fit(Xtrain,ytrain)

cv_score = cross_validate(model, Xtrain, ytrain,cv=10, \
    scoring=['max_error','r2','neg_mean_absolute_error','neg_mean_squared_error'])

# %%
cv_score
# Out:
# {'fit_time': array([0.00150108, 0.00119185, 0.00109696, 0.00108409, 0.00107074,
#         0.00106812, 0.00106788, 0.00107288, 0.0011189 , 0.00107312]),
#  'score_time': array([0.00106597, 0.00100112, 0.000983  , 0.00097895, 0.00096798,
#         0.00097299, 0.00096893, 0.00096822, 0.00103402, 0.00095272]),
#  'test_max_error': array([-43239.50766388, -44122.11167862, -44503.73209168, -44357.26548672,
#         -40020.55534716, -37776.06150278, -35472.14826157, -39861.97662978,
#         -33981.63359865, -44225.34812341]),
#  'test_r2': array([ 0.00491304, -0.02191179, -0.02122347, -0.01043358, -0.01562347,
#         -0.03134641, -0.02136299,  0.02421803,  0.01317696, -0.03313531]),
#  'test_neg_mean_absolute_error': array([-14558.01103084, -14976.46134562, -15729.72172605, -14974.67715706,
#         -12561.90050842, -14731.74306596, -12975.2205163 , -14171.285792  ,
#         -12613.83867516, -14771.23093787]),
# ...

# %%
for key, value in cv_score.items():
    print(f"{key} {np.mean(value)}")
# Out:
# fit_time 0.0011345624923706054
# score_time 0.000989389419555664
# test_max_error -40756.03403842532
# test_r2 -0.01127289862298494
# test_neg_mean_absolute_error -14206.409075528685
# test_neg_mean_squared_error -295354234.78821254

# %%
Xtest[features_list] =scaler.fit_transform(Xtest[features_list])
Xtest.describe()
# Out:
#        Store_Area  Items_Available  Daily_Customer_Count
# count  269.000000       269.000000            269.000000
# mean     0.506834         0.508830              0.459736
# std      0.183897         0.184427              0.171593
# min      0.000000         0.000000              0.000000
# 25%      0.386379         0.387755              0.345070
# 50%      0.511466         0.505539              0.443662
# 75%      0.653231         0.655394              0.591549
# max      1.000000         1.000000              1.000000

# %%
y_pred=model.predict(Xtest)

mse=mean_squared_error(ytest,y_pred)
rmse=math.sqrt(mse)
mae=mean_absolute_error(ytest,y_pred)
Rsquared = r2_score(ytest,y_pred)
Max_err = max_error(ytest,y_pred)

print(f"mse {mse}, rmse {rmse}, mae {mae}, Rsquared {Rsquared}, Max err {Max_err}")
# Out:
# mse 293472879.3844707, rmse 17131.05015416366, mae 13959.160636850647, Rsquared 0.012517209005690644, Max err 52971.85873952691

# %%
#try solvers
from sklearn.linear_model import SGDRegressor

sql_sgd= SGDRegressor(loss="squared_loss")
cv_score_sgd = cross_validate(sql_sgd, Xtrain,ytrain,cv=10, \
    scoring=['max_error','r2','neg_mean_absolute_error','neg_mean_squared_error'])


cv_score_sgd
# Out:
# /Users/lingchin/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:165: FutureWarning: The loss 'squared_loss' was deprecated in v1.0 and will be removed in version 1.2. Use `loss='squared_error'` which is equivalent.
#   warnings.warn(
# /Users/lingchin/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:165: FutureWarning: The loss 'squared_loss' was deprecated in v1.0 and will be removed in version 1.2. Use `loss='squared_error'` which is equivalent.
#   warnings.warn(
# /Users/lingchin/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:165: FutureWarning: The loss 'squared_loss' was deprecated in v1.0 and will be removed in version 1.2. Use `loss='squared_error'` which is equivalent.
#   warnings.warn(
# ...

# %%
for key, value in cv_score_sgd.items():
    print(f"{key} {round(np.mean(value),3)}")
# Out:
# fit_time 0.007
# score_time 0.001
# test_max_error -41324.477
# test_r2 -0.015
# test_neg_mean_absolute_error -14222.461
# test_neg_mean_squared_error -296284057.023

# %%
#Solver = MAE
mae_sgd= SGDRegressor(loss="epsilon_insensitive", epsilon = 0)

cv_mae_sgd = cross_validate(mae_sgd, Xtrain,ytrain,cv=10, \
    scoring=['max_error','r2','neg_mean_absolute_error','neg_mean_squared_error'])


cv_mae_sgd
# Out:
# /Users/lingchin/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:1503: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/lingchin/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:1503: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/lingchin/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:1503: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# ...

# %%
for key, value in cv_mae_sgd.items():
    print(f"{key} {round(np.mean(value),3)}")
# Out:
# fit_time 0.033
# score_time 0.001
# test_max_error -97074.76
# test_r2 -11.966
# test_neg_mean_absolute_error -58694.811
# test_neg_mean_squared_error -3739146714.304

# %%
#KNN
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
#find best n-neighbors for the KNN model
best_k=[]
for knn in range(2,20):
    neigh = KNeighborsRegressor(n_neighbors=knn)
    neigh.fit(Xtrain, ytrain)
    score=cross_val_score(neigh,Xtrain, ytrain, cv=5)
    best_k.append(score.mean())

# %%
plt.plot(best_k);
plt.xlabel('knn')
plt.ylabel('cross_val_score')
# Out:
# Text(0, 0.5, 'cross_val_score')

# %%
best_score=max(best_k)
best_k=best_k.index(best_score)
best_k
# Out:
# 17

# %%
neigh = KNeighborsRegressor(n_neighbors=best_k)
neigh.fit(Xtrain, ytrain)

y_pred=neigh.predict(Xtest)

mse=mean_squared_error(ytest,y_pred)
rmse=math.sqrt(mse)
mae=mean_absolute_error(ytest,y_pred)
Rsquared = r2_score(ytest,y_pred)
Max_err = max_error(ytest,y_pred)

print(f"mse={round(mse,2)}, rmse={round(rmse,2)}, mae={round(mae,2)}, Rsquared={round(Rsquared,3)}, Max err={round(Max_err,2)}")
# Out:
# mse=318232576.14, rmse=17839.07, mae=14584.38, Rsquared=-0.071, Max err=56151.76
